# %%
# Fixes user id data type
import glob
import pandas as pd
print("Pandas Version Number: " + pd.__version__)
# Out:
# Pandas Version Number: 1.4.2

# %%
# Read in average ratings
average_ratings_df = pd.read_csv('../../../data/average_ratings/average_ratings.csv')
display(average_ratings_df)
# Out:
#       user_id    Action  Adventure      Cars    Comedy  Dementia    Demons  \
# 0         0.0  7.700000   7.444444       NaN  7.750000       NaN       NaN
# 1         1.0  7.886364   7.750000       NaN  7.860000       NaN  8.500000
# 2         2.0  8.551724   8.875000       NaN  8.588235       NaN  8.500000
# 3         3.0  7.571429   7.840000  8.000000  7.492228  8.000000  7.692308
# 4         4.0  7.531250   7.769231       NaN  7.685185       NaN  6.666667
# ...       ...       ...        ...       ...       ...       ...       ...
# 5683   6525.0  6.444444   6.500000       NaN  6.951220  7.333333  5.750000
# 5684   6527.0  6.772727   6.723881  7.428571  6.757576  7.666667  6.628571
# 5685   6528.0  7.559211   7.654762  8.142857  7.713636       NaN  7.523810
# 5686   6529.0  5.880952   6.352941       NaN  5.944444  6.500000  7.000000
# 5687   6531.0  7.407407   7.272727       NaN  7.685714  8.857143  7.500000
#
# ...

# %%
# Get user_ids and convert to int
average_ratings_df['user_id'] = average_ratings_df['user_id'].astype(int)
display(average_ratings_df)
# Out:
#       user_id    Action  Adventure      Cars    Comedy  Dementia    Demons  \
# 0           0  7.700000   7.444444       NaN  7.750000       NaN       NaN
# 1           1  7.886364   7.750000       NaN  7.860000       NaN  8.500000
# 2           2  8.551724   8.875000       NaN  8.588235       NaN  8.500000
# 3           3  7.571429   7.840000  8.000000  7.492228  8.000000  7.692308
# 4           4  7.531250   7.769231       NaN  7.685185       NaN  6.666667
# ...       ...       ...        ...       ...       ...       ...       ...
# 5683     6525  6.444444   6.500000       NaN  6.951220  7.333333  5.750000
# 5684     6527  6.772727   6.723881  7.428571  6.757576  7.666667  6.628571
# 5685     6528  7.559211   7.654762  8.142857  7.713636       NaN  7.523810
# 5686     6529  5.880952   6.352941       NaN  5.944444  6.500000  7.000000
# 5687     6531  7.407407   7.272727       NaN  7.685714  8.857143  7.500000
#
# ...

# %%
# Export to file
average_ratings_df.to_csv('../../../data/average_ratings/average_ratings.csv', index=False)
